# %% [markdown]
# ### __Part 1 - Data Collection__
#
# I am using chembl library to download the biological activity data from chembl database

# %%
# !pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.10.9)
# Requirement already satisfied: urllib3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from chembl_webresource_client) (2.2.1)
# Requirement already satisfied: requests>=2.18.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from chembl_webresource_client) (2.31.0)
# Requirement already satisfied: requests-cache~=1.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from chembl_webresource_client) (1.2.1)
# Requirement already satisfied: easydict in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.18.4->chembl_webresource_client) (2024.2.2)
# Requirement already satisfied: attrs>=21.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests-cache~=1.2->chembl_webresource_client) (23.1.0)
# Requirement already satisfied: cattrs>=22.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests-cache~=1.2->chembl_webresource_client) (24.1.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/sam/Library/Python/3.11/lib/python/site-packages (from requests-cache~=1.2->chembl_webresource_client) (3.10.0)
# Requirement already satisfied: url-normalize>=1.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests-cache~=1.2->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.16.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Importing Libraries

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ### Search for Target Protein

# %% [markdown]
# Target protein:  HER2 (ERBB2)
#
# Function: A receptor tyrosine kinase involved in cell growth and differentiation.
#
# Disease Association: Overexpression of HER2 is associated with certain types of breast cancer and is a target for monoclonal antibody therapy (e.g., Herceptin).

# %%
target=new_client.target    
target_query = target.search('CHEMBL1824')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references      organism  \
# 0  [{'xref_id': 'P04626', 'xref_name': None, 'xre...  Homo sapiens
# 1                                                 []  Homo sapiens
# 2                                                 []  Homo sapiens
# 3                                                 []  Homo sapiens
# 4                                                 []  Homo sapiens
#
#                                            pref_name  score  \
# 0            Receptor protein-tyrosine kinase erbB-2   12.0
# 1                                          FASN/HER2    9.0
# 2                          ErbB-2/ErbB-3 heterodimer    8.0
# 3  Epidermal growth factor receptor and ErbB2 (HE...    6.0
# 4                   Epidermal growth factor receptor    5.0
#
#    species_group_flag target_chembl_id  \
# 0               False       CHEMBL1824
# 1               False    CHEMBL4106134
# 2               False    CHEMBL4630723
# 3               False    CHEMBL2111431
# 4               False    CHEMBL2363049
#
#                                    target_components      target_type  tax_id
# 0  [{'accession': 'P04626', 'component_descriptio...   SINGLE PROTEIN    9606
# 1  [{'accession': 'P04626', 'component_descriptio...  PROTEIN COMPLEX    9606
# 2  [{'accession': 'P04626', 'component_descriptio...  PROTEIN COMPLEX    9606
# 3  [{'accession': 'P04626', 'component_descriptio...   PROTEIN FAMILY    9606
# 4  [{'accession': 'P04626', 'component_descriptio...   PROTEIN FAMILY    9606

# %% [markdown]
# #### Select and retrieve data for bioactivity data for HER2

# %% [markdown]
# I am assigning the 0th entry (0-indexed) (which corresponds to the Beta amyloid) to the selected target variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL1824'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %% [markdown]
# choosing a particular standard type "IC50" or "EC50" makes the data uniform as it ensures that there is no mixture of different
# bioactivity units, number in the value column represents the potency so lower the number, the better is the potency of the drug,
#  as value represents the concentration of drug represents the conecentration o required to inhibit the protein

# %%
df=pd.DataFrame.from_dict(res)
df
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 4092  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4093  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4094  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4095  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4096  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id activity_properties assay_chembl_id  \
# 0           32264                  []    CHEMBL845865
# 1           32266                  []    CHEMBL615491
# 2           32271                  []    CHEMBL683802
# 3           32273                  []    CHEMBL615491
# 4           47937                  []    CHEMBL683802
# ...           ...                 ...             ...
# 4092     25073466                  []   CHEMBL5253688
# 4093     25078778                  []   CHEMBL5255145
# 4094     25078779                  []   CHEMBL5255145
# 4095     25078780                  []   CHEMBL5255145
# 4096     25078781                  []   CHEMBL5255145
#
#                                       assay_description assay_type  \
# 0     Inhibition of autophosphorylation of human Her...          F
# 1     Inhibition of ligand induced proliferation in ...          F
# 2     Inhibition of autophosphorylation of human Her...          F
# 3     Inhibition of ligand induced proliferation in ...          F
# 4     Inhibition of autophosphorylation of human Her...          F
# ...                                                 ...        ...
# 4092  Inhibition of human recombinant ERBB2 expresse...          B
# 4093                Inhibition of HER2 (unknown origin)          B
# 4094                Inhibition of HER2 (unknown origin)          B
# 4095                Inhibition of HER2 (unknown origin)          B
# 4096                Inhibition of HER2 (unknown origin)          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                       None                   None  BAO_0000190  ...
# 1                       None                   None  BAO_0000190  ...
# 2                       None                   None  BAO_0000190  ...
# 3                       None                   None  BAO_0000190  ...
# 4                       None                   None  BAO_0000190  ...
# ...                      ...                    ...          ...  ...
# 4092                    None                   None  BAO_0000190  ...
# 4093                    None                   None  BAO_0000190  ...
# 4094                    None                   None  BAO_0000190  ...
# 4095                    None                   None  BAO_0000190  ...
# 4096                    None                   None  BAO_0000190  ...
#
#      target_organism                         target_pref_name target_tax_id  \
# 0       Homo sapiens  Receptor protein-tyrosine kinase erbB-2          9606
# 1       Homo sapiens  Receptor protein-tyrosine kinase erbB-2          9606
# 2       Homo sapiens  Receptor protein-tyrosine kinase erbB-2          9606
# 3       Homo sapiens  Receptor protein-tyrosine kinase erbB-2          9606
# 4       Homo sapiens  Receptor protein-tyrosine kinase erbB-2          9606
# ...              ...                                      ...           ...
# 4092    Homo sapiens  Receptor protein-tyrosine kinase erbB-2          9606
# 4093    Homo sapiens  Receptor protein-tyrosine kinase erbB-2          9606
# 4094    Homo sapiens  Receptor protein-tyrosine kinase erbB-2          9606
# 4095    Homo sapiens  Receptor protein-tyrosine kinase erbB-2          9606
# 4096    Homo sapiens  Receptor protein-tyrosine kinase erbB-2          9606
#
#      text_value  toid  type units    uo_units upper_value   value
# 0          None  None  IC50    uM  UO_0000065        None     0.3
# 1          None  None  IC50    uM  UO_0000065        None     2.5
# 2          None  None  IC50    uM  UO_0000065        None     0.4
# 3          None  None  IC50    uM  UO_0000065        None    1.21
# 4          None  None  IC50    uM  UO_0000065        None     0.1
# ...         ...   ...   ...   ...         ...         ...     ...
# 4092       None  None  IC50    nM  UO_0000065        None  8730.0
# 4093       None  None  IC50    nM  UO_0000065        None    1.31
# 4094       None  None  IC50    nM  UO_0000065        None    1.98
# 4095       None  None  IC50    nM  UO_0000065        None    0.96
# 4096       None  None  IC50    nM  UO_0000065        None    1.42
#
# [4097 rows x 46 columns]

# %% [markdown]
# I am saving the resulting bioactivity data to a CSV file bioactivity_data.csv

# %%
df.to_csv('../../datasets/HER2/bioactivity_data_HER2.csv',index=False)

# %% [markdown]
# ### Handling missing data

# %% [markdown]
# If any compound has missing value for the value column, then drop it

# %%
df2= df.dropna(subset=['canonical_smiles', 'standard_value'])
df2= df2.reset_index(drop=True)
# Convert column to numeric, forcing errors to NaN
df2['standard_value'] = pd.to_numeric(df2['standard_value'], errors='coerce')
df2=df2[df2['standard_value']>0]
df2= df2.reset_index(drop=True)
df2
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 3160  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 3161  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 3162  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 3163  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 3164  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id activity_properties assay_chembl_id  \
# 0           32264                  []    CHEMBL845865
# 1           32266                  []    CHEMBL615491
# 2           32271                  []    CHEMBL683802
# 3           32273                  []    CHEMBL615491
# 4           47937                  []    CHEMBL683802
# ...           ...                 ...             ...
# 3160     25073466                  []   CHEMBL5253688
# 3161     25078778                  []   CHEMBL5255145
# 3162     25078779                  []   CHEMBL5255145
# 3163     25078780                  []   CHEMBL5255145
# 3164     25078781                  []   CHEMBL5255145
#
#                                       assay_description assay_type  \
# 0     Inhibition of autophosphorylation of human Her...          F
# 1     Inhibition of ligand induced proliferation in ...          F
# 2     Inhibition of autophosphorylation of human Her...          F
# 3     Inhibition of ligand induced proliferation in ...          F
# 4     Inhibition of autophosphorylation of human Her...          F
# ...                                                 ...        ...
# 3160  Inhibition of human recombinant ERBB2 expresse...          B
# 3161                Inhibition of HER2 (unknown origin)          B
# 3162                Inhibition of HER2 (unknown origin)          B
# 3163                Inhibition of HER2 (unknown origin)          B
# 3164                Inhibition of HER2 (unknown origin)          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                       None                   None  BAO_0000190  ...
# 1                       None                   None  BAO_0000190  ...
# 2                       None                   None  BAO_0000190  ...
# 3                       None                   None  BAO_0000190  ...
# 4                       None                   None  BAO_0000190  ...
# ...                      ...                    ...          ...  ...
# 3160                    None                   None  BAO_0000190  ...
# 3161                    None                   None  BAO_0000190  ...
# 3162                    None                   None  BAO_0000190  ...
# 3163                    None                   None  BAO_0000190  ...
# 3164                    None                   None  BAO_0000190  ...
#
#      target_organism                         target_pref_name target_tax_id  \
# 0       Homo sapiens  Receptor protein-tyrosine kinase erbB-2          9606
# 1       Homo sapiens  Receptor protein-tyrosine kinase erbB-2          9606
# 2       Homo sapiens  Receptor protein-tyrosine kinase erbB-2          9606
# 3       Homo sapiens  Receptor protein-tyrosine kinase erbB-2          9606
# 4       Homo sapiens  Receptor protein-tyrosine kinase erbB-2          9606
# ...              ...                                      ...           ...
# 3160    Homo sapiens  Receptor protein-tyrosine kinase erbB-2          9606
# 3161    Homo sapiens  Receptor protein-tyrosine kinase erbB-2          9606
# 3162    Homo sapiens  Receptor protein-tyrosine kinase erbB-2          9606
# 3163    Homo sapiens  Receptor protein-tyrosine kinase erbB-2          9606
# 3164    Homo sapiens  Receptor protein-tyrosine kinase erbB-2          9606
#
#      text_value  toid  type units    uo_units upper_value   value
# 0          None  None  IC50    uM  UO_0000065        None     0.3
# 1          None  None  IC50    uM  UO_0000065        None     2.5
# 2          None  None  IC50    uM  UO_0000065        None     0.4
# 3          None  None  IC50    uM  UO_0000065        None    1.21
# 4          None  None  IC50    uM  UO_0000065        None     0.1
# ...         ...   ...   ...   ...         ...         ...     ...
# 3160       None  None  IC50    nM  UO_0000065        None  8730.0
# 3161       None  None  IC50    nM  UO_0000065        None    1.31
# 3162       None  None  IC50    nM  UO_0000065        None    1.98
# 3163       None  None  IC50    nM  UO_0000065        None    0.96
# 3164       None  None  IC50    nM  UO_0000065        None    1.42
#
# [3165 rows x 46 columns]

# %% [markdown]
# ### Data pre-processing of the bioactivity data

# %% [markdown]
# __Labeling compounds as either being active, inactive or intermediate__
#
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be __active__, while
# those greater than 10,000 nM, will be considered to be __inactive__. As for those values in between 1,000 and 10,000 nM will be referred as __intermediate__

# %%
bioactivity_class = []
for i in df2.standard_value:
    if float(i) >= 10000:
        bioactivity_class.append("inactive")
    elif float(i) <= 1000 : 
        bioactivity_class.append("active")
    else :
        bioactivity_class.append("intermediate")

# %% [markdown]
#  Iterate the molecule_chembl_id,canonical_smiles and standard_value columns from df to a another dataframe

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2[selection]

# %%
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 1           CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 2           CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 3           CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 4           CHEMBL67057  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# ...                 ...                                                ...
# 3160      CHEMBL5270270                  COc1cc2ncnc(NCCOc3ccccc3F)c2cc1OC
# 3161      CHEMBL3545154  C=CC(=O)N1CCC(Oc2cc3c(Nc4ccc(Cl)c(Cl)c4F)ncnc3...
# 3162      CHEMBL1173655  CN(C)C/C=C/C(=O)Nc1cc2c(Nc3ccc(F)c(Cl)c3)ncnc2...
# 3163      CHEMBL5282641  C=CC(=O)N1CCC(Oc2cc3c(Nc4ccc(Cl)c(Cl)c4F)ncnc3...
# 3164      CHEMBL5288888  C=CC(=O)N1CCC(Oc2cc3c(Nc4cccc(Cl)c4F)ncnc3cc2O...
#
#       standard_value
# 0             300.00
# 1            2500.00
# 2             400.00
# 3            1210.00
# 4             100.00
# ...              ...
# 3160         8730.00
# 3161            1.31
# 3162            1.98
# 3163            0.96
# 3164            1.42
#
# [3165 rows x 3 columns]

# %%
df4=pd.concat([df3,pd.Series(bioactivity_class)],axis=1)

# %% [markdown]
# #### Saves dataframe to a CSV file

# %%
df4.to_csv('../../datasets/HER2/bioactivity_preprocessed_data_HER2.csv',index=False)

# %% [markdown]
# ### __Part 2- Exploratory Data Analysis__

# %% [markdown]
# ### __Installing Conda and RDKit__

# %%
# !pip install rdkit
# Out:
# Requirement already satisfied: rdkit in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2023.9.6)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from rdkit) (1.26.4)
# Requirement already satisfied: Pillow in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from rdkit) (10.0.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
df = pd.read_csv('../../datasets/HER2/bioactivity_preprocessed_data_HER2.csv')
df = df.rename(columns={'0': 'class'})
df
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 1           CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 2           CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 3           CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 4           CHEMBL67057  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# ...                 ...                                                ...
# 3160      CHEMBL5270270                  COc1cc2ncnc(NCCOc3ccccc3F)c2cc1OC
# 3161      CHEMBL3545154  C=CC(=O)N1CCC(Oc2cc3c(Nc4ccc(Cl)c(Cl)c4F)ncnc3...
# 3162      CHEMBL1173655  CN(C)C/C=C/C(=O)Nc1cc2c(Nc3ccc(F)c(Cl)c3)ncnc2...
# 3163      CHEMBL5282641  C=CC(=O)N1CCC(Oc2cc3c(Nc4ccc(Cl)c(Cl)c4F)ncnc3...
# 3164      CHEMBL5288888  C=CC(=O)N1CCC(Oc2cc3c(Nc4cccc(Cl)c4F)ncnc3cc2O...
#
#       standard_value         class
# 0             300.00        active
# 1            2500.00  intermediate
# 2             400.00        active
# 3            1210.00  intermediate
# 4             100.00        active
# ...              ...           ...
# 3160         8730.00  intermediate
# 3161            1.31        active
# 3162            1.98        active
# 3163            0.96        active
# 3164            1.42        active
#
# [3165 rows x 4 columns]

# %% [markdown]
# ### __Calculate Lipinski Descriptors__

# %% [markdown]
# Christopher Lipinski, a scientist at Pfizer, came up with a set of rule-of-thumb for evaluating the **druglikeness** of compounds. Such druglikeness is based on the Absorption, Distribution, Metabolism and Excretion (ADME) that is also known as the pharmacokinetic profile. Lipinski analyzed all orally active FDA-approved drugs in the formulation of what is to be known as the **Rule-of-Five** or **Lipinski's Rule**.
#
# Lipinski's rule of five is a rule of thumb to evaluate druglikeness or determine if a chemical compound with a certain pharmacological or biological activity has chemical properties and physical properties that would make it a likely orally active drug in humans.
#
# The Lipinski's Rule stated the following:
# * Molecular weight < 500 Dalton
# * Octanol-water partition coefficient (LogP) < 5
# * Hydrogen bond donors < 5
# * Hydrogen bond acceptors < 10
#
# An orally active drug has no more than one violation of the above 5 conditions according to Lipinski's Rule.
#
# (all of the values are multiples of 5 above)

# %% [markdown]
# Importing Libraries

# %%
! pip install py3Dmol
# Out:
# Requirement already satisfied: py3Dmol in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.3.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors,Lipinski,AllChem
import py3Dmol
import re
from rdkit.Chem import Draw
from rdkit.Chem import AllChem

# %% [markdown]
# ### __Calculate Descriptors__

# %%
def lipinski(smiles, verbose=False):
    # Ensure smiles is a pandas Series
    if not isinstance(smiles, pd.Series):
        raise TypeError("Input should be a pandas Series")
    
    moldata = []
    
    # Convert the first SMILES string to an RDKit molecule

    for elem in smiles:
        first_smiles = elem
        molecule = Chem.MolFromSmiles(first_smiles)
        if not molecule:
            continue
        moldata.append(molecule)
    
    baseData = []  # Initialize baseData as an empty list
    
    for mol in moldata:        
        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)
        
        row = np.array([desc_MolWt, desc_MolLogP, desc_NumHDonors, desc_NumHAcceptors])
        baseData.append(row)  # Append each row to baseData
    
    columnNames = ["MW", "LogP", "NumHDonors", "NumHAcceptors"]
    
    # Convert baseData to a numpy array and then to a DataFrame
    baseData = np.array(baseData)
    descriptors = pd.DataFrame(baseData, columns=columnNames)
    
    return descriptors

# Example usage
smiles_series = pd.Series(["CCO"])
descriptors = lipinski(smiles_series, verbose=True)

# %%
df_lipinski=lipinski(pd.Series(df["canonical_smiles"]))

# %%
df_lipinski
# Out:
#            MW     LogP  NumHDonors  NumHAcceptors
# 0     383.814  4.45034         3.0            4.0
# 1     383.814  4.45034         3.0            4.0
# 2     482.903  3.61432         3.0            6.0
# 3     482.903  3.61432         3.0            6.0
# 4     559.630  4.82482         3.0            7.0
# ...       ...      ...         ...            ...
# 3160  343.358  3.27700         1.0            6.0
# 3161  491.350  5.38370         1.0            6.0
# 3162  485.947  4.38990         2.0            7.0
# 3163  547.414  5.54280         1.0            7.0
# 3164  512.969  4.88940         1.0            7.0
#
# [3165 rows x 4 columns]

# %%
df
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 1           CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 2           CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 3           CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 4           CHEMBL67057  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# ...                 ...                                                ...
# 3160      CHEMBL5270270                  COc1cc2ncnc(NCCOc3ccccc3F)c2cc1OC
# 3161      CHEMBL3545154  C=CC(=O)N1CCC(Oc2cc3c(Nc4ccc(Cl)c(Cl)c4F)ncnc3...
# 3162      CHEMBL1173655  CN(C)C/C=C/C(=O)Nc1cc2c(Nc3ccc(F)c(Cl)c3)ncnc2...
# 3163      CHEMBL5282641  C=CC(=O)N1CCC(Oc2cc3c(Nc4ccc(Cl)c(Cl)c4F)ncnc3...
# 3164      CHEMBL5288888  C=CC(=O)N1CCC(Oc2cc3c(Nc4cccc(Cl)c4F)ncnc3cc2O...
#
#       standard_value         class
# 0             300.00        active
# 1            2500.00  intermediate
# 2             400.00        active
# 3            1210.00  intermediate
# 4             100.00        active
# ...              ...           ...
# 3160         8730.00  intermediate
# 3161            1.31        active
# 3162            1.98        active
# 3163            0.96        active
# 3164            1.42        active
#
# [3165 rows x 4 columns]

# %% [markdown]
# ### **Combine DataFrames**
#
# Let's combine the 2 DataFrames df and dp_lipinski

# %%
df_combined = pd.concat([df,df_lipinski], axis=1)

# %%
df_combined
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 1           CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 2           CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 3           CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 4           CHEMBL67057  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# ...                 ...                                                ...
# 3160      CHEMBL5270270                  COc1cc2ncnc(NCCOc3ccccc3F)c2cc1OC
# 3161      CHEMBL3545154  C=CC(=O)N1CCC(Oc2cc3c(Nc4ccc(Cl)c(Cl)c4F)ncnc3...
# 3162      CHEMBL1173655  CN(C)C/C=C/C(=O)Nc1cc2c(Nc3ccc(F)c(Cl)c3)ncnc2...
# 3163      CHEMBL5282641  C=CC(=O)N1CCC(Oc2cc3c(Nc4ccc(Cl)c(Cl)c4F)ncnc3...
# 3164      CHEMBL5288888  C=CC(=O)N1CCC(Oc2cc3c(Nc4cccc(Cl)c4F)ncnc3cc2O...
#
#       standard_value         class       MW     LogP  NumHDonors  \
# 0             300.00        active  383.814  4.45034         3.0
# 1            2500.00  intermediate  383.814  4.45034         3.0
# 2             400.00        active  482.903  3.61432         3.0
# 3            1210.00  intermediate  482.903  3.61432         3.0
# 4             100.00        active  559.630  4.82482         3.0
# ...              ...           ...      ...      ...         ...
# 3160         8730.00  intermediate  343.358  3.27700         1.0
# 3161            1.31        active  491.350  5.38370         1.0
# 3162            1.98        active  485.947  4.38990         2.0
# 3163            0.96        active  547.414  5.54280         1.0
# 3164            1.42        active  512.969  4.88940         1.0
#
#       NumHAcceptors
# 0               4.0
# 1               4.0
# 2               6.0
# 3               6.0
# 4               7.0
# ...             ...
# 3160            6.0
# 3161            6.0
# 3162            7.0
# 3163            7.0
# 3164            7.0
#
# [3165 rows x 8 columns]

# %% [markdown]
# ### **Convert IC50 to pIC50**
# To allow **IC50** data to be more uniformly distributed, we will convert **IC50** to the negative logarithmic scale which is essentially **-log10(IC50)**.
#
# This custom function pIC50() will accept a DataFrame as input and will:
# * Take the IC50 values from the ``standard_value`` column and converts it from nM to M by multiplying the value by 10$^{-9}$
# * Take the molar value and apply -log10
# * Delete the ``standard_value`` column and create a new ``pIC50`` column

# %%
# https://github.com/chaninlab/estrogen-receptor-alpha-qsar/blob/master/02_ER_alpha_RO5.ipynb

import numpy as np

def pIC50(input):
    pIC50 = []

    for i in input['standard_value']:
        molar = i*(10**-9) # Converts nM to M
        pIC50.append(-np.log10(molar))

    input['pIC50'] = pIC50

        
    return input

# %% [markdown]
# Point to note: Values greater than 100,000,000 will be fixed at 100,000,000 otherwise the negative logarithmic value will become negative.

# %%
df_combined.standard_value.describe()
# Out:
# count    3.165000e+03
# mean     8.361227e+03
# std      4.368675e+04
# min      6.000000e-02
# 25%      4.700000e+01
# 50%      2.000000e+02
# 75%      2.500000e+03
# max      1.600000e+06
# Name: standard_value, dtype: float64

# %% [markdown]
# We will first apply the norm_value() function so that the values in the standard_value column is normalized.

# %%
df_norm = df_combined[df['standard_value'] <= 100000000]
df_norm
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 1           CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 2           CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 3           CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 4           CHEMBL67057  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# ...                 ...                                                ...
# 3160      CHEMBL5270270                  COc1cc2ncnc(NCCOc3ccccc3F)c2cc1OC
# 3161      CHEMBL3545154  C=CC(=O)N1CCC(Oc2cc3c(Nc4ccc(Cl)c(Cl)c4F)ncnc3...
# 3162      CHEMBL1173655  CN(C)C/C=C/C(=O)Nc1cc2c(Nc3ccc(F)c(Cl)c3)ncnc2...
# 3163      CHEMBL5282641  C=CC(=O)N1CCC(Oc2cc3c(Nc4ccc(Cl)c(Cl)c4F)ncnc3...
# 3164      CHEMBL5288888  C=CC(=O)N1CCC(Oc2cc3c(Nc4cccc(Cl)c4F)ncnc3cc2O...
#
#       standard_value         class       MW     LogP  NumHDonors  \
# 0             300.00        active  383.814  4.45034         3.0
# 1            2500.00  intermediate  383.814  4.45034         3.0
# 2             400.00        active  482.903  3.61432         3.0
# 3            1210.00  intermediate  482.903  3.61432         3.0
# 4             100.00        active  559.630  4.82482         3.0
# ...              ...           ...      ...      ...         ...
# 3160         8730.00  intermediate  343.358  3.27700         1.0
# 3161            1.31        active  491.350  5.38370         1.0
# 3162            1.98        active  485.947  4.38990         2.0
# 3163            0.96        active  547.414  5.54280         1.0
# 3164            1.42        active  512.969  4.88940         1.0
#
#       NumHAcceptors
# 0               4.0
# 1               4.0
# 2               6.0
# 3               6.0
# 4               7.0
# ...             ...
# 3160            6.0
# 3161            6.0
# 3162            7.0
# 3163            7.0
# 3164            7.0
#
# [3165 rows x 8 columns]

# %%
df_norm.standard_value.describe()
# Out:
# count    3.165000e+03
# mean     8.361227e+03
# std      4.368675e+04
# min      6.000000e-02
# 25%      4.700000e+01
# 50%      2.000000e+02
# 75%      2.500000e+03
# max      1.600000e+06
# Name: standard_value, dtype: float64

# %%
df_final = pIC50(df_norm)
df_final
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 1           CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 2           CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 3           CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 4           CHEMBL67057  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# ...                 ...                                                ...
# 3160      CHEMBL5270270                  COc1cc2ncnc(NCCOc3ccccc3F)c2cc1OC
# 3161      CHEMBL3545154  C=CC(=O)N1CCC(Oc2cc3c(Nc4ccc(Cl)c(Cl)c4F)ncnc3...
# 3162      CHEMBL1173655  CN(C)C/C=C/C(=O)Nc1cc2c(Nc3ccc(F)c(Cl)c3)ncnc2...
# 3163      CHEMBL5282641  C=CC(=O)N1CCC(Oc2cc3c(Nc4ccc(Cl)c(Cl)c4F)ncnc3...
# 3164      CHEMBL5288888  C=CC(=O)N1CCC(Oc2cc3c(Nc4cccc(Cl)c4F)ncnc3cc2O...
#
#       standard_value         class       MW     LogP  NumHDonors  \
# 0             300.00        active  383.814  4.45034         3.0
# 1            2500.00  intermediate  383.814  4.45034         3.0
# 2             400.00        active  482.903  3.61432         3.0
# 3            1210.00  intermediate  482.903  3.61432         3.0
# 4             100.00        active  559.630  4.82482         3.0
# ...              ...           ...      ...      ...         ...
# 3160         8730.00  intermediate  343.358  3.27700         1.0
# 3161            1.31        active  491.350  5.38370         1.0
# 3162            1.98        active  485.947  4.38990         2.0
# 3163            0.96        active  547.414  5.54280         1.0
# 3164            1.42        active  512.969  4.88940         1.0
#
#       NumHAcceptors     pIC50
# 0               4.0  6.522879
# 1               4.0  5.602060
# 2               6.0  6.397940
# 3               6.0  5.917215
# 4               7.0  7.000000
# ...             ...       ...
# 3160            6.0  5.058986
# 3161            6.0  8.882729
# 3162            7.0  8.703335
# 3163            7.0  9.017729
# 3164            7.0  8.847712
#
# [3165 rows x 9 columns]

# %%
df_final.pIC50.describe()
# Out:
# count    3165.000000
# mean        6.494571
# std         1.218773
# min         2.795880
# 25%         5.602060
# 50%         6.698970
# 75%         7.327902
# max        10.221849
# Name: pIC50, dtype: float64

# %%
df_final.to_csv('../../datasets/HER2/HER2_bioactivity_data_3class_pIC50.csv')

# %% [markdown]
# ### **Removing the 'intermediate' bioactivity class**
# Here, we will be removing the ``intermediate`` class from our data set.

# %%
df_2class = df_final[df_final['class'] != 'intermediate']
df_2class
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL68920  Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)...
# 2           CHEMBL69960  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 4           CHEMBL67057  Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(N...
# 7           CHEMBL69629  Cc1cc(C(=O)NCCN2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncn...
# 9           CHEMBL66570  CCN1CCN(C(=O)c2cc(C)c(/C=C3\C(=O)Nc4ncnc(Nc5cc...
# ...                 ...                                                ...
# 3159      CHEMBL4080062  O=C(Nc1cccc(C(F)(F)F)c1)c1cccc2cc(Oc3cc(CO)ncn...
# 3161      CHEMBL3545154  C=CC(=O)N1CCC(Oc2cc3c(Nc4ccc(Cl)c(Cl)c4F)ncnc3...
# 3162      CHEMBL1173655  CN(C)C/C=C/C(=O)Nc1cc2c(Nc3ccc(F)c(Cl)c3)ncnc2...
# 3163      CHEMBL5282641  C=CC(=O)N1CCC(Oc2cc3c(Nc4ccc(Cl)c(Cl)c4F)ncnc3...
# 3164      CHEMBL5288888  C=CC(=O)N1CCC(Oc2cc3c(Nc4cccc(Cl)c4F)ncnc3cc2O...
#
#       standard_value   class       MW     LogP  NumHDonors  NumHAcceptors  \
# 0             300.00  active  383.814  4.45034         3.0            4.0
# 2             400.00  active  482.903  3.61432         3.0            6.0
# 4             100.00  active  559.630  4.82482         3.0            7.0
# 7             100.00  active  525.972  3.20392         4.0            7.0
# 9             100.00  active  509.973  3.91962         3.0            6.0
# ...              ...     ...      ...      ...         ...            ...
# 3159          500.00  active  439.393  5.18550         2.0            5.0
# 3161            1.31  active  491.350  5.38370         1.0            6.0
# 3162            1.98  active  485.947  4.38990         2.0            7.0
# 3163            0.96  active  547.414  5.54280         1.0            7.0
# 3164            1.42  active  512.969  4.88940         1.0            7.0
#
#          pIC50
# 0     6.522879
# 2     6.397940
# 4     7.000000
# 7     7.000000
# 9     7.000000
# ...        ...
# 3159  6.301030
# 3161  8.882729
# 3162  8.703335
# 3163  9.017729
# 3164  8.847712
#
# [2713 rows x 9 columns]

# %% [markdown]
# Let's write this to CSV file.

# %%
df_2class.to_csv('../../datasets/HER2/HER2_bioactivity_data_2class_pIC50.csv')

# %% [markdown]
# ## **Exploratory Data Analysis (Chemical Space Analysis) via Lipinski descriptors**

# %% [markdown]
# ### **Import library**

# %%
import seaborn as sns
sns.set(style='ticks')
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Frequency plot of the 2 bioactivity classes**

# %%
plt.figure(figsize=(5.5, 5.5))

sns.countplot(x='class', data=df_2class, edgecolor='black')

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('Frequency', fontsize=14, fontweight='bold')

plt.savefig('plot_bioactivity_class.pdf')

# %% [markdown]
# ### **Scatter plot of MW versus LogP**
#
# It can be seen that the 2 bioactivity classes are spanning similar chemical spaces (with same outliers) as evident by the scatter plot of MW vs LogP below.

# %%
plt.figure(figsize=(5.5, 5.5))

sns.scatterplot(x='MW', y='LogP', data=df_2class, hue='class', size='pIC50', edgecolor='black', alpha=0.7)

plt.xlabel('MW', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
plt.savefig('plot_MW_vs_LogP.pdf')

# %% [markdown]
# ### **Box plots**

# %% [markdown]
# #### **pIC50 value**

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'pIC50', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('pIC50 value', fontsize=14, fontweight='bold')

plt.savefig('plot_ic50.pdf')

# %% [markdown]
# #### Can clearly see in above box plot that the inactive class is inactive majorly due to the reason of its low pIC50 that is higher concentration of that compound is reqd to inhibit the protein, making the drug less effective

# %% [markdown]
# ### __Mann-Whitney U Test__
#
# This test tests whether there is a significant difference between 2 independent samples (active and inactive class here). It is a non-parametric counterpart to the t-test for independent samples.
#
# But there is an important difference between the 2 tests, the t-test tests whether the mean values of the 2 samples differ significantly while mann whitney u test tests whether there is a significant rank sum difference.
#
# Null Hypothesis (H0) in MWU test: in the 2 samples, the rank sums do not differ significantly.
#
# If p value is greater than the significance level of 0.05, null hypotheses cannot be rejected based on the sample

# %% [markdown]
# **Statistical analysis | Mann-Whitney U Test**

# %%
def mannwhitney(descriptor, verbose=False):
  # https://machinelearningmastery.com/nonparametric-statistical-significance-tests-in-python/
  from numpy.random import seed
  from numpy.random import randn
  from scipy.stats import mannwhitneyu

# seed the random number generator
  seed(1)

# actives and inactives
  selection = [descriptor, 'class']
  df = df_2class[selection]
  active = df[df['class'] == 'active']
  active = active[descriptor]

  selection = [descriptor, 'class']
  df = df_2class[selection]
  inactive = df[df['class'] == 'inactive']
  inactive = inactive[descriptor]
  
# compare samples
  stat, p = mannwhitneyu(active, inactive)
  print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
  alpha = 0.05
  print(p)
  print(len(active))
  if p > alpha:
    interpretation = 'Same distribution (fail to reject H0)'
  else:
    interpretation = 'Different distribution (reject H0)'
  
  results = pd.DataFrame({'Descriptor':descriptor,
                          'Statistics':stat,
                          'p':p,
                          'alpha':alpha,
                          'Interpretation':interpretation}, index=[0])
  filename = '../../datasets/HER2/mannwhitneyu_' + descriptor + '.csv'
  results.to_csv(filename)

  return results

# %%
mannwhitney('pIC50')
# Out:
# Statistics=1143702.000, p=0.000
# 2.742733709079749e-277
# 2191
#   Descriptor  Statistics              p  alpha  \
# 0      pIC50   1143702.0  2.742734e-277   0.05
#
#                        Interpretation
# 0  Different distribution (reject H0)

# %% [markdown]
# #### **MW**

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'MW', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('MW', fontsize=14, fontweight='bold')

plt.savefig('plot_MW.pdf')

# %%
mannwhitney('MW')
# Out:
# Statistics=929910.000, p=0.000
# 8.434141218283814e-110
# 2191
#   Descriptor  Statistics              p  alpha  \
# 0         MW    929910.0  8.434141e-110   0.05
#
#                        Interpretation
# 0  Different distribution (reject H0)

# %% [markdown]
# #### **LogP**

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'LogP', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')

plt.savefig('plot_LogP.pdf')

# %% [markdown]
# **Statistical analysis | Mann-Whitney U Test**

# %%
mannwhitney('LogP')
# Out:
# Statistics=801164.500, p=0.000
# 3.996843501607823e-46
# 2191
#   Descriptor  Statistics             p  alpha  \
# 0       LogP    801164.5  3.996844e-46   0.05
#
#                        Interpretation
# 0  Different distribution (reject H0)

# %% [markdown]
# #### **NumHDonors**

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'NumHDonors', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHDonors', fontsize=14, fontweight='bold')

plt.savefig('plot_NumHDonors.pdf')

# %% [markdown]
# **Statistical analysis | Mann-Whitney U Test**

# %%
mannwhitney('NumHDonors')
# Out:
# Statistics=727107.500, p=0.000
# 5.733585630930873e-26
# 2191
#    Descriptor  Statistics             p  alpha  \
# 0  NumHDonors    727107.5  5.733586e-26   0.05
#
#                        Interpretation
# 0  Different distribution (reject H0)

# %% [markdown]
# #### **NumHAcceptors**

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'NumHAcceptors', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHAcceptors', fontsize=14, fontweight='bold')

plt.savefig('plot_NumHAcceptors.pdf')

# %% [markdown]
# **Statistical analysis | Mann-Whitney U Test**

# %%
mannwhitney('NumHAcceptors')
# Out:
# Statistics=927746.000, p=0.000
# 4.868195325120912e-111
# 2191
#       Descriptor  Statistics              p  alpha  \
# 0  NumHAcceptors    927746.0  4.868195e-111   0.05
#
#                        Interpretation
# 0  Different distribution (reject H0)

# %% [markdown]
# #### **Interpretation of Statistical Results**

# %% [markdown]
# ##### **Box Plots**
#
# ###### **pIC50 values**
#
# Taking a look at pIC50 values, the **actives** and **inactives** displayed ***statistically significant difference***, which is to be expected since threshold values (``IC50 < 1,000 nM = Actives while IC50 > 10,000 nM = Inactives``, corresponding to ``pIC50 > 6 = Actives and pIC50 < 5 = Inactives``) were used to define actives and inactives.
#
# ###### **Lipinski's descriptors**
#
# 4 out of the 4 Lipinski's descriptors (Mol_wt, No. of H acceptors, No. of H donors, Octanol-water partition coefficient (LogP)) exhibited ***statistically significant difference*** between the **actives** and **inactives** based on Mann-Whitney U Test, which is allowed significant difference of descriptors since violation of atmost 1 condition is allowed in Lipsinki's Rule of five.
