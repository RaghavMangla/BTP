# %% [markdown]
# ### __Part 1 - Data Collection__
#
# I am using chembl library to download the biological activity data from chembl database

# %%
# !pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from chembl_webresource_client) (2.2.1)
# Requirement already satisfied: requests>=2.18.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from chembl_webresource_client) (2.31.0)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Collecting easydict (from chembl_webresource_client)
#   Downloading easydict-1.13-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.18.4->chembl_webresource_client) (2024.2.2)
# Requirement already satisfied: attrs>=21.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests-cache~=1.2->chembl_webresource_client) (23.1.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-24.1.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /Users/sam/Library/Python/3.11/lib/python/site-packages (from requests-cache~=1.2->chembl_webresource_client) (3.10.0)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.16.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 5.9 MB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 10.1 MB/s eta 0:00:00
# Downloading easydict-1.13-py3-none-any.whl (6.8 kB)
# Downloading cattrs-24.1.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 8.9 MB/s eta 0:00:00
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Installing collected packages: easydict, url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-24.1.0 chembl_webresource_client-0.10.9 easydict-1.13 requests-cache-1.2.1 url-normalize-1.4.3
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Importing Libraries

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ### Search for Target Protein

# %% [markdown]
# Target protein: Beta-Amyloid (APP)
#
# Function: A fragment of the amyloid precursor protein, which is involved in neural growth and repair.
#
# Disease Association: Accumulation of beta-amyloid plaques in the brain is a hallmark of Alzheimer’s disease.

# %%
target=new_client.target    
target_query = target.search('Beta-Amyloid')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                        cross_references           organism  \
# 0     [{'xref_id': 'P05067', 'xref_name': None, 'xre...       Homo sapiens
# 1                                                    []  Rattus norvegicus
# 2                                                    []       Mus musculus
# 3                                                    []       Homo sapiens
# 4     [{'xref_id': 'P37840', 'xref_name': None, 'xre...       Homo sapiens
# ...                                                 ...                ...
# 1313                                                 []       Homo sapiens
# 1314                                                 []       Homo sapiens
# 1315                                                 []       Homo sapiens
# 1316                                                 []       Homo sapiens
# 1317                                                 []           Bacteria
#
#                                           pref_name  score  \
# 0                           Amyloid-beta A4 protein   20.0
# 1                           Amyloid-beta A4 protein   20.0
# 2                           Amyloid-beta A4 protein   20.0
# 3        Amyloid beta-binding alcohol dehydrogenase   19.0
# 4                                   Alpha-synuclein   18.0
# ...                                             ...    ...
# 1313                                        Caspase    1.0
# 1314                                         mTORC1    1.0
# 1315                                         mTORC2    1.0
# 1316  Amiloride-sensitive sodium channel, ENaC mRNA    1.0
# 1317                         Bacterial 70S ribosome    0.0
#
#       species_group_flag target_chembl_id  \
# 0                  False       CHEMBL2487
# 1                  False    CHEMBL3638365
# 2                  False    CHEMBL4523942
# 3                  False    CHEMBL4295598
# 4                  False       CHEMBL6152
# ...                  ...              ...
# 1313               False    CHEMBL3831289
# 1314               False    CHEMBL4296661
# 1315               False    CHEMBL4523999
# 1316               False    CHEMBL4834389
# 1317                True    CHEMBL2363135
#
#                                       target_components  \
# 0     [{'accession': 'P05067', 'component_descriptio...
# 1     [{'accession': 'P08592', 'component_descriptio...
# 2     [{'accession': 'P12023', 'component_descriptio...
# 3     [{'accession': 'Q2L8D9', 'component_descriptio...
# 4     [{'accession': 'P37840', 'component_descriptio...
# ...                                                 ...
# 1313  [{'accession': 'P49662', 'component_descriptio...
# 1314  [{'accession': 'P42345', 'component_descriptio...
# 1315  [{'accession': 'P42345', 'component_descriptio...
# 1316  [{'accession': 'ENSG00000166828', 'component_d...
# 1317  [{'accession': 'P0A7V0', 'component_descriptio...
#
#                        target_type   tax_id
# 0                   SINGLE PROTEIN   9606.0
# 1                   SINGLE PROTEIN  10116.0
# 2                   SINGLE PROTEIN  10090.0
# 3                   SINGLE PROTEIN   9606.0
# 4                   SINGLE PROTEIN   9606.0
# ...                            ...      ...
# 1313                PROTEIN FAMILY   9606.0
# 1314               PROTEIN COMPLEX   9606.0
# 1315               PROTEIN COMPLEX   9606.0
# 1316                  NUCLEIC-ACID   9606.0
# 1317  PROTEIN NUCLEIC-ACID COMPLEX      2.0
#
# [1318 rows x 9 columns]

# %% [markdown]
# #### Select and retrieve data for bioactivity data for Beta Amyloid (APP) (2nd entry)

# %% [markdown]
# I am assigning the first entry (0-indexed) (which corresponds to the Beta amyloid) to the selected target variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL2487'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %% [markdown]
# choosing a particular standard type "IC50" or "EC50" makes the data uniform as it ensures that there is no mixture of different
# bioactivity units, number in the value column represents the potency so lower the number, the better is the potency of the drug,
#  as value represents the concentration of drug represents the conecentration o required to inhibit the protein

# %%
df=pd.DataFrame.from_dict(res)
df
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1598  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1599  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1600  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1601  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1602  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# 0          357577                                                 []
# 1          357580                                                 []
# 2          358965                                                 []
# 3          368887                                                 []
# 4          375954                                                 []
# ...           ...                                                ...
# 1598     25079667  [{'comments': None, 'relation': '=', 'result_f...
# 1599     25079668  [{'comments': None, 'relation': '=', 'result_f...
# 1600     25079669  [{'comments': None, 'relation': '=', 'result_f...
# 1601     25079670  [{'comments': None, 'relation': '=', 'result_f...
# 1602     25079671  [{'comments': None, 'relation': '=', 'result_f...
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# 1       CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# 2       CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# 3       CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# 4       CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# ...              ...                                                ...
# 1598   CHEMBL5255354  Inhibition of Amyloid beta (1 to 42) (unknown ...
# 1599   CHEMBL5255354  Inhibition of Amyloid beta (1 to 42) (unknown ...
# 1600   CHEMBL5255354  Inhibition of Amyloid beta (1 to 42) (unknown ...
# 1601   CHEMBL5255354  Inhibition of Amyloid beta (1 to 42) (unknown ...
# 1602   CHEMBL5255354  Inhibition of Amyloid beta (1 to 42) (unknown ...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 1598          B                    None                   None  BAO_0000190
# 1599          B                    None                   None  BAO_0000190
# 1600          B                    None                   None  BAO_0000190
# 1601          B                    None                   None  BAO_0000190
# 1602          B                    None                   None  BAO_0000190
#
#       ... target_organism         target_pref_name target_tax_id text_value  \
# 0     ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1     ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 2     ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 3     ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 4     ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# ...   ...             ...                      ...           ...        ...
# 1598  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1599  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1600  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1601  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1602  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
#
#       toid  type units    uo_units upper_value value
# 0     None  IC50    uM  UO_0000065        None   5.0
# 1     None  IC50    uM  UO_0000065        None   2.7
# 2     None  IC50    uM  UO_0000065        None   1.8
# 3     None  IC50    uM  UO_0000065        None  11.0
# 4     None  IC50    uM  UO_0000065        None  10.0
# ...    ...   ...   ...         ...         ...   ...
# 1598  None  IC50    uM  UO_0000065        None  1.03
# 1599  None  IC50    uM  UO_0000065        None  0.99
# 1600  None  IC50    uM  UO_0000065        None   0.1
# 1601  None  IC50    uM  UO_0000065        None  1.56
# 1602  None  IC50    uM  UO_0000065        None  0.18
#
# [1603 rows x 46 columns]

# %% [markdown]
# I am saving the resulting bioactivity data to a CSV file bioactivity_data.csv

# %%
df.to_csv('../../datasets/APP/bioactivity_data_APP.csv',index=False)

# %% [markdown]
# ### Handling missing data

# %% [markdown]
# If any compound has missing value for the value column, then drop it

# %%
df2= df.dropna(subset=['canonical_smiles', 'standard_value'])
df2= df2.reset_index(drop=True)
# Convert column to numeric, forcing errors to NaN
df2['standard_value'] = pd.to_numeric(df2['standard_value'], errors='coerce')
df2=df2[df2['standard_value']>0]
df2= df2.reset_index(drop=True)
df2
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1420  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1421  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1422  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1423  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1424  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# 0          357577                                                 []
# 1          357580                                                 []
# 2          358965                                                 []
# 3          368887                                                 []
# 4          375954                                                 []
# ...           ...                                                ...
# 1420     25079667  [{'comments': None, 'relation': '=', 'result_f...
# 1421     25079668  [{'comments': None, 'relation': '=', 'result_f...
# 1422     25079669  [{'comments': None, 'relation': '=', 'result_f...
# 1423     25079670  [{'comments': None, 'relation': '=', 'result_f...
# 1424     25079671  [{'comments': None, 'relation': '=', 'result_f...
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# 1       CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# 2       CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# 3       CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# 4       CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# ...              ...                                                ...
# 1420   CHEMBL5255354  Inhibition of Amyloid beta (1 to 42) (unknown ...
# 1421   CHEMBL5255354  Inhibition of Amyloid beta (1 to 42) (unknown ...
# 1422   CHEMBL5255354  Inhibition of Amyloid beta (1 to 42) (unknown ...
# 1423   CHEMBL5255354  Inhibition of Amyloid beta (1 to 42) (unknown ...
# 1424   CHEMBL5255354  Inhibition of Amyloid beta (1 to 42) (unknown ...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 1420          B                    None                   None  BAO_0000190
# 1421          B                    None                   None  BAO_0000190
# 1422          B                    None                   None  BAO_0000190
# 1423          B                    None                   None  BAO_0000190
# 1424          B                    None                   None  BAO_0000190
#
#       ... target_organism         target_pref_name target_tax_id text_value  \
# 0     ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1     ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 2     ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 3     ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 4     ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# ...   ...             ...                      ...           ...        ...
# 1420  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1421  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1422  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1423  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
# 1424  ...    Homo sapiens  Amyloid-beta A4 protein          9606       None
#
#       toid  type units    uo_units upper_value value
# 0     None  IC50    uM  UO_0000065        None   5.0
# 1     None  IC50    uM  UO_0000065        None   2.7
# 2     None  IC50    uM  UO_0000065        None   1.8
# 3     None  IC50    uM  UO_0000065        None  11.0
# 4     None  IC50    uM  UO_0000065        None  10.0
# ...    ...   ...   ...         ...         ...   ...
# 1420  None  IC50    uM  UO_0000065        None  1.03
# 1421  None  IC50    uM  UO_0000065        None  0.99
# 1422  None  IC50    uM  UO_0000065        None   0.1
# 1423  None  IC50    uM  UO_0000065        None  1.56
# 1424  None  IC50    uM  UO_0000065        None  0.18
#
# [1425 rows x 46 columns]

# %% [markdown]
# So in the above dataset, 22 rows had missing data, which is now removed

# %% [markdown]
# ### Data pre-processing of the bioactivity data

# %% [markdown]
# __Labeling compounds as either being active, inactive or intermediate__
#
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be __active__, while
# those greater than 10,000 nM, will be considered to be __inactive__. As for those values in between 1,000 and 10,000 nM will be referred as __intermediate__

# %%
bioactivity_class = []
for i in df2.standard_value:
    if float(i) >= 10000:
        bioactivity_class.append("inactive")
    elif float(i) <= 1000 : 
        bioactivity_class.append("active")
    else :
        bioactivity_class.append("intermediate")

# %% [markdown]
#  Iterate the molecule_chembl_id,canonical_smiles and standard_value columns from df to a another dataframe

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2[selection]

# %%
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL311039          CC12CCC(C1)C(C)(C)C2NS(=O)(=O)c1ccc(F)cc1
# 1          CHEMBL450926    CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1cccs1
# 2          CHEMBL310242  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 3           CHEMBL74874  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 4           CHEMBL75183  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# ...                 ...                                                ...
# 1420      CHEMBL5274298  COC(=O)c1cc(O)cc(OC)c1C(=O)c1c(O)cc(CO[C@H]2O[...
# 1421      CHEMBL5283067  COC(=O)c1c(Sc2c(O)cc(OC)c(C(=O)c3c(O)cc(C)cc3O...
# 1422      CHEMBL5273520  COC(=O)c1c(O)cc(C)c(Sc2c(O)cc(OC)c(Oc3c(O)cc(C...
# 1423      CHEMBL5282081  COC(=O)c1c(O)cc(C)cc1C(=O)c1cc(O)cc2oc3cc4c(c(...
# 1424      CHEMBL5274654  Cc1cc(O)c(C(=O)c2c(O)cc3c(c2O)C(=O)c2c(O)cc(C)...
#
#       standard_value
# 0             5000.0
# 1             2700.0
# 2             1800.0
# 3            11000.0
# 4            10000.0
# ...              ...
# 1420          1030.0
# 1421           990.0
# 1422           100.0
# 1423          1560.0
# 1424           180.0
#
# [1425 rows x 3 columns]

# %%
df4=pd.concat([df3,pd.Series(bioactivity_class)],axis=1)

# %% [markdown]
# #### Saves dataframe to a CSV file

# %%
df4.to_csv('../../datasets/APP/bioactivity_preprocessed_data_APP.csv',index=False)

# %% [markdown]
# ### __Part 2- Exploratory Data Analysis__

# %% [markdown]
# ### __Installing Conda and RDKit__

# %%
# !pip install rdkit
# Out:
# Requirement already satisfied: rdkit in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2023.9.6)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from rdkit) (1.26.4)
# Requirement already satisfied: Pillow in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from rdkit) (10.0.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
df = pd.read_csv('../../datasets/APP/bioactivity_preprocessed_data_APP.csv')
df = df.rename(columns={'0': 'class'})
df
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL311039          CC12CCC(C1)C(C)(C)C2NS(=O)(=O)c1ccc(F)cc1
# 1          CHEMBL450926    CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1cccs1
# 2          CHEMBL310242  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 3           CHEMBL74874  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 4           CHEMBL75183  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# ...                 ...                                                ...
# 1420      CHEMBL5274298  COC(=O)c1cc(O)cc(OC)c1C(=O)c1c(O)cc(CO[C@H]2O[...
# 1421      CHEMBL5283067  COC(=O)c1c(Sc2c(O)cc(OC)c(C(=O)c3c(O)cc(C)cc3O...
# 1422      CHEMBL5273520  COC(=O)c1c(O)cc(C)c(Sc2c(O)cc(OC)c(Oc3c(O)cc(C...
# 1423      CHEMBL5282081  COC(=O)c1c(O)cc(C)cc1C(=O)c1cc(O)cc2oc3cc4c(c(...
# 1424      CHEMBL5274654  Cc1cc(O)c(C(=O)c2c(O)cc3c(c2O)C(=O)c2c(O)cc(C)...
#
#       standard_value         class
# 0             5000.0  intermediate
# 1             2700.0  intermediate
# 2             1800.0  intermediate
# 3            11000.0      inactive
# 4            10000.0      inactive
# ...              ...           ...
# 1420          1030.0  intermediate
# 1421           990.0        active
# 1422           100.0        active
# 1423          1560.0  intermediate
# 1424           180.0        active
#
# [1425 rows x 4 columns]

# %% [markdown]
# ### __Calculate Lipinski Descriptors__

# %% [markdown]
# Christopher Lipinski, a scientist at Pfizer, came up with a set of rule-of-thumb for evaluating the **druglikeness** of compounds. Such druglikeness is based on the Absorption, Distribution, Metabolism and Excretion (ADME) that is also known as the pharmacokinetic profile. Lipinski analyzed all orally active FDA-approved drugs in the formulation of what is to be known as the **Rule-of-Five** or **Lipinski's Rule**.
#
# Lipinski's rule of five is a rule of thumb to evaluate druglikeness or determine if a chemical compound with a certain pharmacological or biological activity has chemical properties and physical properties that would make it a likely orally active drug in humans.
#
# The Lipinski's Rule stated the following:
# * Molecular weight < 500 Dalton
# * Octanol-water partition coefficient (LogP) < 5
# * Hydrogen bond donors < 5
# * Hydrogen bond acceptors < 10
#
# An orally active drug has no more than one violation of the above 5 conditions according to Lipinski's Rule.
#
# (all of the values are multiples of 5 above)

# %% [markdown]
# Importing Libraries

# %%
! pip install py3Dmol
# Out:
# Collecting py3Dmol
#   Downloading py3Dmol-2.3.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Downloading py3Dmol-2.3.0-py2.py3-none-any.whl (7.0 kB)
# Installing collected packages: py3Dmol
# Successfully installed py3Dmol-2.3.0
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors,Lipinski,AllChem
import py3Dmol
import re
from rdkit.Chem import Draw
from rdkit.Chem import AllChem

# %% [markdown]
# ### __Calculate Descriptors__

# %%
def lipinski(smiles, verbose=False):
    # Ensure smiles is a pandas Series
    if not isinstance(smiles, pd.Series):
        raise TypeError("Input should be a pandas Series")
    
    moldata = []
    
    # Convert the first SMILES string to an RDKit molecule

    for elem in smiles:
        first_smiles = elem
        molecule = Chem.MolFromSmiles(first_smiles)
        if not molecule:
            continue
        moldata.append(molecule)
    
    baseData = []  # Initialize baseData as an empty list
    
    for mol in moldata:        
        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)
        
        row = np.array([desc_MolWt, desc_MolLogP, desc_NumHDonors, desc_NumHAcceptors])
        baseData.append(row)  # Append each row to baseData
    
    columnNames = ["MW", "LogP", "NumHDonors", "NumHAcceptors"]
    
    # Convert baseData to a numpy array and then to a DataFrame
    baseData = np.array(baseData)
    descriptors = pd.DataFrame(baseData, columns=columnNames)
    
    return descriptors

# Example usage
smiles_series = pd.Series(["CCO"])
descriptors = lipinski(smiles_series, verbose=True)

# %%
df_lipinski=lipinski(pd.Series(df["canonical_smiles"]))

# %%
df_lipinski
# Out:
#            MW     LogP  NumHDonors  NumHAcceptors
# 0     311.422  3.31880         1.0            2.0
# 1     299.461  3.24120         1.0            3.0
# 2     311.422  3.31880         1.0            2.0
# 3     327.877  3.83310         1.0            2.0
# 4     372.328  3.94220         1.0            2.0
# ...       ...      ...         ...            ...
# 1420  510.448 -0.85390         7.0           13.0
# 1421  680.640  4.43222         6.0           15.0
# 1422  624.620  5.52076         7.0           13.0
# 1423  552.491  4.81824         4.0           10.0
# 1424  556.479  3.48004         7.0           11.0
#
# [1425 rows x 4 columns]

# %%
df
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL311039          CC12CCC(C1)C(C)(C)C2NS(=O)(=O)c1ccc(F)cc1
# 1          CHEMBL450926    CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1cccs1
# 2          CHEMBL310242  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 3           CHEMBL74874  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 4           CHEMBL75183  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# ...                 ...                                                ...
# 1420      CHEMBL5274298  COC(=O)c1cc(O)cc(OC)c1C(=O)c1c(O)cc(CO[C@H]2O[...
# 1421      CHEMBL5283067  COC(=O)c1c(Sc2c(O)cc(OC)c(C(=O)c3c(O)cc(C)cc3O...
# 1422      CHEMBL5273520  COC(=O)c1c(O)cc(C)c(Sc2c(O)cc(OC)c(Oc3c(O)cc(C...
# 1423      CHEMBL5282081  COC(=O)c1c(O)cc(C)cc1C(=O)c1cc(O)cc2oc3cc4c(c(...
# 1424      CHEMBL5274654  Cc1cc(O)c(C(=O)c2c(O)cc3c(c2O)C(=O)c2c(O)cc(C)...
#
#       standard_value         class
# 0             5000.0  intermediate
# 1             2700.0  intermediate
# 2             1800.0  intermediate
# 3            11000.0      inactive
# 4            10000.0      inactive
# ...              ...           ...
# 1420          1030.0  intermediate
# 1421           990.0        active
# 1422           100.0        active
# 1423          1560.0  intermediate
# 1424           180.0        active
#
# [1425 rows x 4 columns]

# %% [markdown]
# ### **Combine DataFrames**
#
# Let's combine the 2 DataFrames df and dp_lipinski

# %%
df_combined = pd.concat([df,df_lipinski], axis=1)

# %%
df_combined
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL311039          CC12CCC(C1)C(C)(C)C2NS(=O)(=O)c1ccc(F)cc1
# 1          CHEMBL450926    CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1cccs1
# 2          CHEMBL310242  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 3           CHEMBL74874  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 4           CHEMBL75183  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# ...                 ...                                                ...
# 1420      CHEMBL5274298  COC(=O)c1cc(O)cc(OC)c1C(=O)c1c(O)cc(CO[C@H]2O[...
# 1421      CHEMBL5283067  COC(=O)c1c(Sc2c(O)cc(OC)c(C(=O)c3c(O)cc(C)cc3O...
# 1422      CHEMBL5273520  COC(=O)c1c(O)cc(C)c(Sc2c(O)cc(OC)c(Oc3c(O)cc(C...
# 1423      CHEMBL5282081  COC(=O)c1c(O)cc(C)cc1C(=O)c1cc(O)cc2oc3cc4c(c(...
# 1424      CHEMBL5274654  Cc1cc(O)c(C(=O)c2c(O)cc3c(c2O)C(=O)c2c(O)cc(C)...
#
#       standard_value         class       MW     LogP  NumHDonors  \
# 0             5000.0  intermediate  311.422  3.31880         1.0
# 1             2700.0  intermediate  299.461  3.24120         1.0
# 2             1800.0  intermediate  311.422  3.31880         1.0
# 3            11000.0      inactive  327.877  3.83310         1.0
# 4            10000.0      inactive  372.328  3.94220         1.0
# ...              ...           ...      ...      ...         ...
# 1420          1030.0  intermediate  510.448 -0.85390         7.0
# 1421           990.0        active  680.640  4.43222         6.0
# 1422           100.0        active  624.620  5.52076         7.0
# 1423          1560.0  intermediate  552.491  4.81824         4.0
# 1424           180.0        active  556.479  3.48004         7.0
#
#       NumHAcceptors
# 0               2.0
# 1               3.0
# 2               2.0
# 3               2.0
# 4               2.0
# ...             ...
# 1420           13.0
# 1421           15.0
# 1422           13.0
# 1423           10.0
# 1424           11.0
#
# [1425 rows x 8 columns]

# %% [markdown]
# ### **Convert IC50 to pIC50**
# To allow **IC50** data to be more uniformly distributed, we will convert **IC50** to the negative logarithmic scale which is essentially **-log10(IC50)**.
#
# This custom function pIC50() will accept a DataFrame as input and will:
# * Take the IC50 values from the ``standard_value`` column and converts it from nM to M by multiplying the value by 10$^{-9}$
# * Take the molar value and apply -log10
# * Delete the ``standard_value`` column and create a new ``pIC50`` column

# %%
# https://github.com/chaninlab/estrogen-receptor-alpha-qsar/blob/master/02_ER_alpha_RO5.ipynb

import numpy as np

def pIC50(input):
    pIC50 = []

    for i in input['standard_value']:
        molar = i*(10**-9) # Converts nM to M
        pIC50.append(-np.log10(molar))

    input['pIC50'] = pIC50

        
    return input

# %% [markdown]
# Point to note: Values greater than 100,000,000 will be fixed at 100,000,000 otherwise the negative logarithmic value will become negative.

# %%
df_combined.standard_value.describe()
# Out:
# count    1.425000e+03
# mean     2.204250e+04
# std      7.949555e+04
# min      3.000000e-01
# 25%      2.700000e+02
# 50%      4.780000e+03
# 75%      1.650000e+04
# max      1.655000e+06
# Name: standard_value, dtype: float64

# %% [markdown]
# We will first apply the norm_value() function so that the values in the standard_value column is normalized.

# %%
df_norm = df_combined[df['standard_value'] <= 100000000]
df_norm
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL311039          CC12CCC(C1)C(C)(C)C2NS(=O)(=O)c1ccc(F)cc1
# 1          CHEMBL450926    CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1cccs1
# 2          CHEMBL310242  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 3           CHEMBL74874  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 4           CHEMBL75183  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# ...                 ...                                                ...
# 1420      CHEMBL5274298  COC(=O)c1cc(O)cc(OC)c1C(=O)c1c(O)cc(CO[C@H]2O[...
# 1421      CHEMBL5283067  COC(=O)c1c(Sc2c(O)cc(OC)c(C(=O)c3c(O)cc(C)cc3O...
# 1422      CHEMBL5273520  COC(=O)c1c(O)cc(C)c(Sc2c(O)cc(OC)c(Oc3c(O)cc(C...
# 1423      CHEMBL5282081  COC(=O)c1c(O)cc(C)cc1C(=O)c1cc(O)cc2oc3cc4c(c(...
# 1424      CHEMBL5274654  Cc1cc(O)c(C(=O)c2c(O)cc3c(c2O)C(=O)c2c(O)cc(C)...
#
#       standard_value         class       MW     LogP  NumHDonors  \
# 0             5000.0  intermediate  311.422  3.31880         1.0
# 1             2700.0  intermediate  299.461  3.24120         1.0
# 2             1800.0  intermediate  311.422  3.31880         1.0
# 3            11000.0      inactive  327.877  3.83310         1.0
# 4            10000.0      inactive  372.328  3.94220         1.0
# ...              ...           ...      ...      ...         ...
# 1420          1030.0  intermediate  510.448 -0.85390         7.0
# 1421           990.0        active  680.640  4.43222         6.0
# 1422           100.0        active  624.620  5.52076         7.0
# 1423          1560.0  intermediate  552.491  4.81824         4.0
# 1424           180.0        active  556.479  3.48004         7.0
#
#       NumHAcceptors
# 0               2.0
# 1               3.0
# 2               2.0
# 3               2.0
# 4               2.0
# ...             ...
# 1420           13.0
# 1421           15.0
# 1422           13.0
# 1423           10.0
# 1424           11.0
#
# [1425 rows x 8 columns]

# %%
df_norm.standard_value.describe()
# Out:
# count    1.425000e+03
# mean     2.204250e+04
# std      7.949555e+04
# min      3.000000e-01
# 25%      2.700000e+02
# 50%      4.780000e+03
# 75%      1.650000e+04
# max      1.655000e+06
# Name: standard_value, dtype: float64

# %%
df_final = pIC50(df_norm)
df_final
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL311039          CC12CCC(C1)C(C)(C)C2NS(=O)(=O)c1ccc(F)cc1
# 1          CHEMBL450926    CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1cccs1
# 2          CHEMBL310242  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 3           CHEMBL74874  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 4           CHEMBL75183  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# ...                 ...                                                ...
# 1420      CHEMBL5274298  COC(=O)c1cc(O)cc(OC)c1C(=O)c1c(O)cc(CO[C@H]2O[...
# 1421      CHEMBL5283067  COC(=O)c1c(Sc2c(O)cc(OC)c(C(=O)c3c(O)cc(C)cc3O...
# 1422      CHEMBL5273520  COC(=O)c1c(O)cc(C)c(Sc2c(O)cc(OC)c(Oc3c(O)cc(C...
# 1423      CHEMBL5282081  COC(=O)c1c(O)cc(C)cc1C(=O)c1cc(O)cc2oc3cc4c(c(...
# 1424      CHEMBL5274654  Cc1cc(O)c(C(=O)c2c(O)cc3c(c2O)C(=O)c2c(O)cc(C)...
#
#       standard_value         class       MW     LogP  NumHDonors  \
# 0             5000.0  intermediate  311.422  3.31880         1.0
# 1             2700.0  intermediate  299.461  3.24120         1.0
# 2             1800.0  intermediate  311.422  3.31880         1.0
# 3            11000.0      inactive  327.877  3.83310         1.0
# 4            10000.0      inactive  372.328  3.94220         1.0
# ...              ...           ...      ...      ...         ...
# 1420          1030.0  intermediate  510.448 -0.85390         7.0
# 1421           990.0        active  680.640  4.43222         6.0
# 1422           100.0        active  624.620  5.52076         7.0
# 1423          1560.0  intermediate  552.491  4.81824         4.0
# 1424           180.0        active  556.479  3.48004         7.0
#
#       NumHAcceptors     pIC50
# 0               2.0  5.301030
# 1               3.0  5.568636
# 2               2.0  5.744727
# 3               2.0  4.958607
# 4               2.0  5.000000
# ...             ...       ...
# 1420           13.0  5.987163
# 1421           15.0  6.004365
# 1422           13.0  7.000000
# 1423           10.0  5.806875
# 1424           11.0  6.744727
#
# [1425 rows x 9 columns]

# %%
df_final.pIC50.describe()
# Out:
# count    1425.000000
# mean        5.711224
# std         1.303668
# min         2.781202
# 25%         4.782516
# 50%         5.320572
# 75%         6.568636
# max         9.522879
# Name: pIC50, dtype: float64

# %%
df_final.to_csv('../../datasets/APP/APP_bioactivity_data_3class_pIC50.csv')

# %% [markdown]
# ### **Removing the 'intermediate' bioactivity class**
# Here, we will be removing the ``intermediate`` class from our data set.

# %%
df_2class = df_final[df_final['class'] != 'intermediate']
df_2class
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 3           CHEMBL74874  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 4           CHEMBL75183  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 5             CHEMBL563                   CC(C(=O)O)c1ccc(-c2ccccc2)c(F)c1
# 6          CHEMBL196279           CC(C(=O)O)c1ccc(-c2ccc(Cl)c(Cl)c2)c(F)c1
# 7          CHEMBL195970           CC(C(=O)O)c1ccc(-c2cc(Cl)cc(Cl)c2)c(F)c1
# ...                 ...                                                ...
# 1415      CHEMBL5283881  CC(C)C[C@H](NC(=O)[C@H](Cc1ccccc1)C[C@@H](O)[C...
# 1416       CHEMBL297453  O=C(O[C@@H]1Cc2c(O)cc(O)cc2O[C@@H]1c1cc(O)c(O)...
# 1421      CHEMBL5283067  COC(=O)c1c(Sc2c(O)cc(OC)c(C(=O)c3c(O)cc(C)cc3O...
# 1422      CHEMBL5273520  COC(=O)c1c(O)cc(C)c(Sc2c(O)cc(OC)c(Oc3c(O)cc(C...
# 1424      CHEMBL5274654  Cc1cc(O)c(C(=O)c2c(O)cc3c(c2O)C(=O)c2c(O)cc(C)...
#
#       standard_value     class       MW     LogP  NumHDonors  NumHAcceptors  \
# 3            11000.0  inactive  327.877  3.83310         1.0            2.0
# 4            10000.0  inactive  372.328  3.94220         1.0            2.0
# 5           305000.0  inactive  244.265  3.68080         1.0            1.0
# 6            75000.0  inactive  313.155  4.98760         1.0            1.0
# 7            77000.0  inactive  313.155  4.98760         1.0            1.0
# ...              ...       ...      ...      ...         ...            ...
# 1415            67.0    active  671.879  5.56660         4.0            6.0
# 1416           140.0    active  458.375  2.23320         8.0           11.0
# 1421           990.0    active  680.640  4.43222         6.0           15.0
# 1422           100.0    active  624.620  5.52076         7.0           13.0
# 1424           180.0    active  556.479  3.48004         7.0           11.0
#
#          pIC50
# 3     4.958607
# 4     5.000000
# 5     3.515700
# 6     4.124939
# 7     4.113509
# ...        ...
# 1415  7.173925
# 1416  6.853872
# 1421  6.004365
# 1422  7.000000
# 1424  6.744727
#
# [1006 rows x 9 columns]

# %% [markdown]
# Let's write this to CSV file.

# %%
df_2class.to_csv('../../datasets/APP/APP_bioactivity_data_2class_pIC50.csv')

# %% [markdown]
# ## **Exploratory Data Analysis (Chemical Space Analysis) via Lipinski descriptors**

# %% [markdown]
# ### **Import library**

# %%
import seaborn as sns
sns.set(style='ticks')
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Frequency plot of the 2 bioactivity classes**

# %%
plt.figure(figsize=(5.5, 5.5))

sns.countplot(x='class', data=df_2class, edgecolor='black')

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('Frequency', fontsize=14, fontweight='bold')

plt.savefig('plot_bioactivity_class.pdf')

# %% [markdown]
# ### **Scatter plot of MW versus LogP**
#
# It can be seen that the 2 bioactivity classes are spanning similar chemical spaces (with same outliers) as evident by the scatter plot of MW vs LogP below.

# %%
plt.figure(figsize=(5.5, 5.5))

sns.scatterplot(x='MW', y='LogP', data=df_2class, hue='class', size='pIC50', edgecolor='black', alpha=0.7)

plt.xlabel('MW', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
plt.savefig('plot_MW_vs_LogP.pdf')

# %% [markdown]
# ### **Box plots**

# %% [markdown]
# #### **pIC50 value**

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'pIC50', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('pIC50 value', fontsize=14, fontweight='bold')

plt.savefig('plot_ic50.pdf')

# %% [markdown]
# #### Can clearly see in above box plot that the inactive class is inactive majorly due to the reason of its low pIC50 that is higher concentration of that compound is reqd to inhibit the protein, making the drug less effective

# %% [markdown]
# ### __Mann-Whitney U Test__
#
# This test tests whether there is a significant difference between 2 independent samples (active and inactive class here). It is a non-parametric counterpart to the t-test for independent samples.
#
# But there is an important difference between the 2 tests, the t-test tests whether the mean values of the 2 samples differ significantly while mann whitney u test tests whether there is a significant rank sum difference.
#
# Null Hypothesis (H0) in MWU test: in the 2 samples, the rank sums do not differ significantly.
#
# If p value is greater than the significance level of 0.05, null hypotheses cannot be rejected based on the sample

# %% [markdown]
# **Statistical analysis | Mann-Whitney U Test**

# %%
def mannwhitney(descriptor, verbose=False):
  # https://machinelearningmastery.com/nonparametric-statistical-significance-tests-in-python/
  from numpy.random import seed
  from numpy.random import randn
  from scipy.stats import mannwhitneyu

# seed the random number generator
  seed(1)

# actives and inactives
  selection = [descriptor, 'class']
  df = df_2class[selection]
  active = df[df['class'] == 'active']
  active = active[descriptor]

  selection = [descriptor, 'class']
  df = df_2class[selection]
  inactive = df[df['class'] == 'inactive']
  inactive = inactive[descriptor]
  
# compare samples
  stat, p = mannwhitneyu(active, inactive)
  print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
  alpha = 0.05
  print(p)
  print(len(active))
  if p > alpha:
    interpretation = 'Same distribution (fail to reject H0)'
  else:
    interpretation = 'Different distribution (reject H0)'
  
  results = pd.DataFrame({'Descriptor':descriptor,
                          'Statistics':stat,
                          'p':p,
                          'alpha':alpha,
                          'Interpretation':interpretation}, index=[0])
  filename = '../../datasets/APP/mannwhitneyu_' + descriptor + '.csv'
  results.to_csv(filename)

  return results

# %%
mannwhitney('pIC50')
# Out:
# Statistics=252333.000, p=0.000
# 1.5530819410412796e-165
# 477
#   Descriptor  Statistics              p  alpha  \
# 0      pIC50    252333.0  1.553082e-165   0.05
#
#                        Interpretation
# 0  Different distribution (reject H0)

# %% [markdown]
# #### **MW**

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'MW', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('MW', fontsize=14, fontweight='bold')

plt.savefig('plot_MW.pdf')

# %%
mannwhitney('MW')
# Out:
# Statistics=166800.500, p=0.000
# 1.043570293277477e-18
# 477
#   Descriptor  Statistics             p  alpha  \
# 0         MW    166800.5  1.043570e-18   0.05
#
#                        Interpretation
# 0  Different distribution (reject H0)

# %% [markdown]
# #### **LogP**

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'LogP', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')

plt.savefig('plot_LogP.pdf')

# %% [markdown]
# **Statistical analysis | Mann-Whitney U Test**

# %%
mannwhitney('LogP')
# Out:
# Statistics=135454.500, p=0.044
# 0.04355777700060073
# 477
#   Descriptor  Statistics         p  alpha                      Interpretation
# 0       LogP    135454.5  0.043558   0.05  Different distribution (reject H0)

# %% [markdown]
# #### **NumHDonors**

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'NumHDonors', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHDonors', fontsize=14, fontweight='bold')

plt.savefig('plot_NumHDonors.pdf')

# %% [markdown]
# **Statistical analysis | Mann-Whitney U Test**

# %%
mannwhitney('NumHDonors')
# Out:
# Statistics=99435.500, p=0.000
# 1.7117929309475302e-09
# 477
#    Descriptor  Statistics             p  alpha  \
# 0  NumHDonors     99435.5  1.711793e-09   0.05
#
#                        Interpretation
# 0  Different distribution (reject H0)

# %% [markdown]
# #### **NumHAcceptors**

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'NumHAcceptors', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHAcceptors', fontsize=14, fontweight='bold')

plt.savefig('plot_NumHAcceptors.pdf')

# %% [markdown]
# **Statistical analysis | Mann-Whitney U Test**

# %%
mannwhitney('NumHAcceptors')
# Out:
# Statistics=160634.500, p=0.000
# 3.015642032276519e-14
# 477
#       Descriptor  Statistics             p  alpha  \
# 0  NumHAcceptors    160634.5  3.015642e-14   0.05
#
#                        Interpretation
# 0  Different distribution (reject H0)

# %% [markdown]
# #### **Interpretation of Statistical Results**

# %% [markdown]
# ##### **Box Plots**
#
# ###### **pIC50 values**
#
# Taking a look at pIC50 values, the **actives** and **inactives** displayed ***statistically significant difference***, which is to be expected since threshold values (``IC50 < 1,000 nM = Actives while IC50 > 10,000 nM = Inactives``, corresponding to ``pIC50 > 6 = Actives and pIC50 < 5 = Inactives``) were used to define actives and inactives.
#
# ###### **Lipinski's descriptors**
#
# 4 out of the 4 Lipinski's descriptors (Mol_wt, No. of H acceptors, No. of H donors, Octanol-water partition coefficient (LogP)) exhibited ***statistically significant difference*** between the **actives** and **inactives** based on Mann-Whitney U Test, which is allowed significant difference of descriptors since violation of at max 1 condition is allowed in Lipsinki's Rule of five.
